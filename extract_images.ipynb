# %%
def save_images_from_event(fn, tag, output_dir='./'):
    assert(os.path.isdir(output_dir))

    image_str = tf.placeholder(tf.string)
    im_tf = tf.image.decode_image(image_str)

    sess = tf.InteractiveSession()
    with sess.as_default():
        count = 0
        for e in tf.train.summary_iterator(fn):
            for v in e.summary.value:
                if v.tag == tag:
                    im = im_tf.eval({image_str: v.image.encoded_image_string})
                    output_fn = os.path.realpath('{}/images/image_{:05d}.png'.format(output_dir, count))
                    print("Saving '{}'".format(output_fn))
                    scipy.misc.imsave(output_fn, im)
                    count += 1

# %%
import tensorflow as tf
import scipy.misc
import os
save_images_from_event("./tensorboard/20171219-032248/events.out.tfevents.1513653775.ip-172-31-28-87", "Generated_images/image/22")
# Out:
# Saving '/Users/drufener/dangan/images/image_00000.png'
# Saving '/Users/drufener/dangan/images/image_00001.png'
# Saving '/Users/drufener/dangan/images/image_00002.png'
# Saving '/Users/drufener/dangan/images/image_00003.png'
# Saving '/Users/drufener/dangan/images/image_00004.png'
# Saving '/Users/drufener/dangan/images/image_00005.png'
# Saving '/Users/drufener/dangan/images/image_00006.png'
# Saving '/Users/drufener/dangan/images/image_00007.png'
# Saving '/Users/drufener/dangan/images/image_00008.png'
# Saving '/Users/drufener/dangan/images/image_00009.png'
# Saving '/Users/drufener/dangan/images/image_00010.png'
# Saving '/Users/drufener/dangan/images/image_00011.png'
# Saving '/Users/drufener/dangan/images/image_00012.png'
# Saving '/Users/drufener/dangan/images/image_00013.png'
# Saving '/Users/drufener/dangan/images/image_00014.png'
# Saving '/Users/drufener/dangan/images/image_00015.png'
# Saving '/Users/drufener/dangan/images/image_00016.png'
# ...
